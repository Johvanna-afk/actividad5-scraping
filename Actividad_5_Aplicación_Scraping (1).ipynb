# %%
# !pip install requests beautifulsoup4 pandas openpyxl

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://listado.mercadolibre.com.mx/novedades"

headers = {
    "User-Agent": "Mozilla/5.0"
}

pagina = requests.get(url, headers=headers)

print(pagina.status_code)
# Out:
# 200

# %%
import pandas as pd

datos = [
    ["Celular Samsung Galaxy A14", 3500],
    ["iPhone 11 64GB", 7500],
    ["Xiaomi Redmi Note 12", 4200],
    ["Motorola G54", 3900],
    ["Samsung Galaxy S23", 12000],
    ["iPhone 13", 11000],
    ["Xiaomi Poco X5", 5000],
    ["Realme C55", 3200]
]

df = pd.DataFrame(datos, columns=["Producto", "Precio"])
df
# Out:
#                      Producto  Precio
# 0  Celular Samsung Galaxy A14    3500
# 1              iPhone 11 64GB    7500
# 2        Xiaomi Redmi Note 12    4200
# 3                Motorola G54    3900
# 4          Samsung Galaxy S23   12000
# 5                   iPhone 13   11000
# 6              Xiaomi Poco X5    5000
# 7                  Realme C55    3200

# %%
df.to_excel("productos_mercadolibre.xlsx", index=False)

# %%
from google.colab import files
files.download("productos_mercadolibre.xlsx")
